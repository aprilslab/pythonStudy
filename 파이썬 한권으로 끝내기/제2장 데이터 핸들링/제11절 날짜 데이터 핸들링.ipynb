# %% [markdown]
# ## 현재 날짜 데이터 추출하기

# %%
from datetime import datetime
datetime.today()
# Out:
# datetime.datetime(2022, 6, 7, 12, 7, 14, 356071)

# %%
datetime.today().year
# Out:
# 2022

# %% [markdown]
# ## 날짜 형식으로 변환하기
#
# **(1)pandas에서 데이터를 날짜 형식으로**
#
# `df['DateTime'] = pd.to_datetime(df['Datetime'], format="%Y-%m-%d %H:%M:%S")`
#
# **(2) 문자열을 날짜로 변환**
#
# `datetime.strptime('날자 문자열', '포맷')`

# %%
datetime.strptime('2022-01-01 00:00:00', '%Y-%m-%d %H:%M:%S')
# Out:
# datetime.datetime(2022, 1, 1, 0, 0)

# %% [markdown]
# **(3) 날짜 형식을 문자열로 변환**
#
# `datetime객체.strftime('포맷')`

# %%
time = datetime.today()
time.strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2022-06-07 12:07:14'

# %% [markdown]
# <div>
# <img src="attachment:date-format.jpg" alt="date-format.jpg" width="800"/>
# </div>

# %% [markdown]
# ## 날짜 데이터의 연산
# `datetime.timedelta(days=0, seconds=0, microseconds=0, milliseconds=0, minutes=0, hours=0, weeks=0)`

# %%
from datetime import timedelta
time = datetime.today()
time + timedelta(days=100)
# Out:
# datetime.datetime(2022, 9, 15, 12, 7, 14, 448066)
