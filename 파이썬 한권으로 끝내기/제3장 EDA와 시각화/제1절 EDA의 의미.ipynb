# %% [markdown]
# ## EDA의 의미
#
# EDA(Exploratory Data Analysis)란 데이터 분석의 가장 첫번째 단계
#
# 데이터의 특징과 내재된 관계를 알아내기 위해 그래프와 통계적 분석 방법을 활용하여 데이터를 탐구하는 것
#
# <div>
# <img src="attachment:eda%EC%9D%98%EC%A3%BC%EC%A0%9C.jpg" width="800" />
# </div>
